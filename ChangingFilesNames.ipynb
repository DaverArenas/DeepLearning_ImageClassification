# %% [markdown]
# <a href="https://colab.research.google.com/github/DaverArenas/DeepLearning_ImageClassification/blob/main/ChangingFilesNames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls ""
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C2C4-8805
#
#  Directory of C:\Users\Cristina Gomez\Downloads
#
# 07/23/2022  09:45 PM    <DIR>          .
# 07/12/2022  10:36 PM    <DIR>          ..
# 07/23/2022  09:35 PM    <DIR>          .ipynb_checkpoints
# 07/15/2022  08:02 AM            12,083 4804075.png
# 07/04/2022  07:22 PM        13,056,603 analisis.csv
# 07/22/2022  02:49 PM            18,883 Autoliquidaciones_57274863_Consolidado.pdf
# 07/12/2022  11:19 AM       336,023,552 AW.accdb
# 06/23/2022  09:28 PM         3,401,708 Basic EDA - DS4A nuevo.docx
# 07/06/2022  09:12 PM            51,968 cambiar dashboard.docx
# 07/19/2022  12:14 PM         1,340,885 CamScanner 07-19-2022 12.08.pdf
# 07/20/2022  11:02 PM            19,909 Caso Analista Tecnico Imagenes 2022 CristinaGomez.docx
# 07/18/2022  09:48 PM           155,613 CertificadoPos_1035390205.pdf
# 07/18/2022  01:04 PM           275,792 ciclo3-master.zip
# 07/19/2022  09:16 AM            42,600 cita mama.jpg
# ...

# %%
import os

# %%
os.listdir(r'C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo')
# Out:
# ['CR7 (1).jpeg',
#  'CR7 (1).jpg',
#  'CR7 (1).png',
#  'CR7 (10).jpeg',
#  'CR7 (10).jpg',
#  'CR7 (10).png',
#  'CR7 (100).jpeg',
#  'CR7 (100).jpg',
#  'CR7 (1000).jpg',
#  'CR7 (1001).jpg',
#  'CR7 (1002).jpg',
#  'CR7 (1003).jpg',
#  'CR7 (1004).jpg',
#  'CR7 (1005).jpg',
#  'CR7 (1006).jpg',
#  'CR7 (1007).jpg',
#  'CR7 (1008).jpg',
#  'CR7 (1009).jpg',
#  'CR7 (101).jpeg',
#  'CR7 (101).jpg',
#  'CR7 (1010).jpg',
#  'CR7 (1011).jpg',
#  'CR7 (1012).jpg',
#  'CR7 (1013).jpg',
#  'CR7 (1014).jpg',
#  'CR7 (1015).jpg',
#  'CR7 (1016).jpg',
#  'CR7 (1017).jpg',
#  'CR7 (1018).jpg',
#  'CR7 (1019).jpg',
#  'CR7 (102).jpeg',
#  'CR7 (102).jpg',
#  'CR7 (1020).jpg',
#  'CR7 (1021).jpg',
#  'CR7 (1022).jpg',
#  'CR7 (1023).jpg',
#  'CR7 (1024).jpg',
#  'CR7 (1025).jpg',
#  'CR7 (1026).jpg',
#  'CR7 (1027).jpg',
#  'CR7 (1028).jpg',
#  'CR7 (1029).jpg',
#  'CR7 (103).jpeg',
#  'CR7 (103).jpg',
#  'CR7 (1030).jpg',
#  'CR7 (1031).jpg',
#  'CR7 (1032).jpg',
#  'CR7 (1033).jpg',
# ...

# %%
path_messi = r"C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi"

# %%
path_ronaldo = r"C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo"

# %%
print(path_ronaldo)
# Out:
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo

# %%
x = 0
for i in os.listdir(path_messi):
  print(i)
# Out:
# messi_ (1)
# messi_ (10)
# messi_ (100)
# messi_ (1000)
# messi_ (1001)
# messi_ (1002)
# messi_ (1003)
# messi_ (1004)
# messi_ (1005)
# messi_ (1006)
# messi_ (1007)
# messi_ (1008)
# messi_ (1009)
# messi_ (101)
# messi_ (1010)
# messi_ (1011)
# messi_ (1012)
# messi_ (1013)
# messi_ (1014)
# messi_ (1015)
# messi_ (1016)
# messi_ (1017)
# messi_ (1018)
# messi_ (1019)
# messi_ (102)
# messi_ (1020)
# messi_ (1021)
# messi_ (1022)
# messi_ (1023)
# messi_ (1024)
# messi_ (1025)
# messi_ (1026)
# messi_ (1027)
# messi_ (1028)
# messi_ (1029)
# messi_ (103)
# messi_ (1030)
# messi_ (1031)
# messi_ (1032)
# messi_ (1033)
# messi_ (1034)
# messi_ (1035)
# messi_ (1036)
# messi_ (1037)
# messi_ (1038)
# messi_ (1039)
# messi_ (104)
# messi_ (1040)
# messi_ (1041)
# messi_ (1042)
# messi_ (1043)
# messi_ (1044)
# messi_ (1045)
# messi_ (1046)
# messi_ (1047)
# messi_ (1048)
# messi_ (1049)
# messi_ (105)
# messi_ (1050)
# messi_ (1051)
# messi_ (1052)
# messi_ (1053)
# messi_ (1054)
# ...

# %%
file_oldname = os.path.join(path_messi, f'\000154282W.jpg')

# %%
print(file_oldname)
# Out:
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\154282W.jpg

# %%
#ESTO NOS PERMITE GENERAR UN LABEL A LOS ARCHIVOS DENTRO DE CADA CARPETA
x = 0
file_path = r"C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_"
file_path2 = r"C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi"
for i in os.listdir(path_messi):
    oldFile = file_path2 + f'\{i}'
    newFile = file_path + str(x) + '.jpg'
    print(oldFile)
    print(newFile)
    os.rename(oldFile, newFile)
    x = x + 1
# Out:
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (1)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_0.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (10)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_1.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (100)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_2.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (1000)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_3.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (1001)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_4.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (1002)
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\LeoMessi_5.jpg
# C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi_ (1003)
# ...

# %%
os.rename(r"C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\22c96a3883df1626a99311551a8fb32b320a1413.jpg", r"C:\Users\Cristina Gomez\Downloads\LionelMessi\LionelMessi\messi1.jpg")

# %%
#ESTO NOS PERMITE GENERAR UN LABEL A LOS ARCHIVOS DENTRO DE CADA CARPETA
x = 0
file_path = r"C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_"
file_path2 = r"C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo"
for i in os.listdir(path_ronaldo):
    oldFile = file_path2 + f'\{i}'
    newFile = file_path + str(x) + '.jpg'
    print(oldFile)
    print(newFile)
    os.rename(oldFile, newFile)
    x = x + 1
# Out:
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (1).jpeg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_0.jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (1).jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_1.jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (1).png
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_2.jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (10).jpeg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_3.jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (10).jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_4.jpg
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7 (10).png
# C:\Users\Cristina Gomez\Downloads\CristianoRonaldo\CristianoRonaldo\CR7_5.jpg
# ...
